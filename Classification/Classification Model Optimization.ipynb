# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for statistical data visualization
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate

# %%
df = pd.read_excel('Features_All.xlsx')
df
# Out:
#              T    T/Tmax        T/Tmin    T/Tavg  Class
# 0     10.46761  1.000000  1.547831e+06  1.608469      0
# 1     10.12358  0.967134  1.496960e+06  1.555605      0
# 2      8.07791  0.771705  1.194469e+06  1.241264      0
# 3      7.93801  0.758340  1.173783e+06  1.219767      0
# 4      7.84026  0.749002  1.159328e+06  1.204747      0
# ...        ...       ...           ...       ...    ...
# 3995   6.51940  0.629329  1.097189e+06  1.061953      7
# 3996   6.97138  0.672959  1.173256e+06  1.135577      7
# 3997   7.38910  0.713282  1.243556e+06  1.203620      7
# 3998   7.56858  0.730608  1.273762e+06  1.232855      7
# 3999   7.60745  0.734360  1.280304e+06  1.239187      7
#
# [4000 rows x 5 columns]

# %%
df2 = df.sample(frac=1).reset_index(drop=True)
df2
# Out:
#             T    T/Tmax        T/Tmin    T/Tavg  Class
# 0     3.38228  0.309312  5.963296e+05  0.528682      1
# 1     9.08968  0.882252  1.480727e+06  1.443216      3
# 2     8.13557  0.744003  1.434382e+06  1.271666      1
# 3     8.22664  0.785914  1.216462e+06  1.264118      0
# 4     5.73669  0.524624  1.011435e+06  0.896699      1
# ...       ...       ...           ...       ...    ...
# 3995  7.38489  0.705499  1.091994e+06  1.134774      0
# 3996  7.61463  0.735053  1.281512e+06  1.240356      7
# 3997  8.08568  0.791950  1.334691e+06  1.237016      2
# 3998  7.91910  0.764444  1.332753e+06  1.289952      7
# 3999  7.85141  0.757910  1.321361e+06  1.278926      7
#
# [4000 rows x 5 columns]

# %%
x=df2.iloc[ : , 0:4]
x
# Out:
#             T    T/Tmax        T/Tmin    T/Tavg
# 0     3.38228  0.309312  5.963296e+05  0.528682
# 1     9.08968  0.882252  1.480727e+06  1.443216
# 2     8.13557  0.744003  1.434382e+06  1.271666
# 3     8.22664  0.785914  1.216462e+06  1.264118
# 4     5.73669  0.524624  1.011435e+06  0.896699
# ...       ...       ...           ...       ...
# 3995  7.38489  0.705499  1.091994e+06  1.134774
# 3996  7.61463  0.735053  1.281512e+06  1.240356
# 3997  8.08568  0.791950  1.334691e+06  1.237016
# 3998  7.91910  0.764444  1.332753e+06  1.289952
# 3999  7.85141  0.757910  1.321361e+06  1.278926
#
# [4000 rows x 4 columns]

# %%
y=df2['Class']
y
# Out:
# 0       1
# 1       3
# 2       1
# 3       0
# 4       1
#        ..
# 3995    0
# 3996    7
# 3997    2
# 3998    7
# 3999    7
# Name: Class, Length: 4000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.to_excel('X_train_clf.xlsx')
y_train.to_excel('y_train_clf.xlsx')
x_test.to_excel('x_test_clf.xlsx')
y_test.to_excel('y_test_clf.xlsx')

# %%
x_train = pd.read_excel('X_train_clf.xlsx')
x_test = pd.read_excel('x_test_clf.xlsx')
y_train = pd.read_excel('y_train_clf.xlsx')
y_test = pd.read_excel('y_test_clf.xlsx')

# %% [markdown]
# ### **RFC**

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(n_estimators= 100, random_state=163,min_samples_split= 2, min_samples_leaf= 1, max_features= 'log2', max_depth= 32, criterion='gini')
RFC.fit(x_train, y_train)
RFC_pred = RFC.predict(x_test)
RFC_acc= accuracy_score(y_test, RFC_pred)
RFC_acc
# Out:
# <ipython-input-64-6dcadd8fa56b>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC.fit(x_train, y_train)
# 0.92625

# %%
print(classification_report(y_test, RFC_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        82
#            1       0.95      0.89      0.92        98
#            2       0.91      0.93      0.92        97
#            3       0.89      0.90      0.90       113
#            4       0.93      0.93      0.93        96
#            5       0.99      0.97      0.98        96
#            6       0.92      0.94      0.93       108
#            7       0.89      0.93      0.91       110
#
#     accuracy                           0.93       800
#    macro avg       0.93      0.93      0.93       800
# weighted avg       0.93      0.93      0.93       800

# %%
max_accuracy = 0
best_random_state = 0

# Iterate through random states from 0 to 500
for random_state in range(501):
    # Create a Random Forest Classifier with the current random state
    clf = RandomForestClassifier(criterion = 'gini', max_features = 'log2',max_depth = 32, random_state=random_state)

    # Train the model
    clf.fit(x_train, y_train)

    # Make predictions on the test set
    y_pred = clf.predict(x_test)

    # Evaluate the model's performance
    accuracy = accuracy_score(y_test, y_pred)

    # Update max accuracy and corresponding random state if the current accuracy is higher
    if accuracy > max_accuracy:
        max_accuracy = accuracy
        best_random_state = random_state

# Print the maximum accuracy and corresponding random state
print(f"Best Random State: {best_random_state}, Maximum Accuracy: {max_accuracy}")
# Out:
# <ipython-input-12-e94e7984b70a>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
# <ipython-input-12-e94e7984b70a>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
# <ipython-input-12-e94e7984b70a>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
# <ipython-input-12-e94e7984b70a>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)
# ...

# %%
RFC_pred1 = RFC.predict(x_train)
RFC_acc1= accuracy_score(y_train, RFC_pred1)
RFC_acc1
# Out:
# 0.9996875

# %%
param_dist = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}

# %%
from sklearn.model_selection import RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=rf_classifier, param_distributions=param_dist, n_iter=100, cv=5, n_jobs=-1, random_state=42)
random_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 10, 20, 30],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [50, 100, 200]},
#                    random_state=42)

# %%
print("Best Hyperparameters:")
print(random_search.best_params_)
# Out:
# Best Hyperparameters:
# {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'gini'}

# %%
best_rf_classifier = random_search.best_estimator_
accuracy = best_rf_classifier.score(x_test, y_test)
print(f"Accuracy on Test Data: {accuracy:.2f}")
# Out:
# Accuracy on Test Data: 0.91

# %% [markdown]
# ## **DTC**

# %%
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier(criterion='entropy', max_depth=32, max_features=None, random_state=202)
DTC.fit(x_train, y_train)
DTC_pred = DTC.predict(x_test)
DTC_acc= accuracy_score(y_test, DTC_pred)
DTC_acc
# Out:
# 0.88625

# %%
print(classification_report(y_test, DTC_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89        82
#            1       0.90      0.84      0.87        98
#            2       0.90      0.90      0.90        97
#            3       0.84      0.82      0.83       113
#            4       0.88      0.91      0.89        96
#            5       0.98      0.96      0.97        96
#            6       0.91      0.91      0.91       108
#            7       0.83      0.87      0.85       110
#
#     accuracy                           0.89       800
#    macro avg       0.89      0.89      0.89       800
# weighted avg       0.89      0.89      0.89       800

# %%
param_dist_DTC = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
from sklearn.model_selection import RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=DTC, param_distributions=param_dist_DTC, n_iter=100, cv=5, n_jobs=-1, random_state=42)
random_search.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 72 is smaller than n_iter=100. Running 72 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=DecisionTreeClassifier(criterion='entropy',
#                                                     max_depth=32,
#                                                     random_state=8),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10]},
#                    random_state=42)

# %%
print("Best Hyperparameters:")
print(random_search.best_params_)
# Out:
# Best Hyperparameters:
# {'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': None, 'criterion': 'entropy'}

# %%
best_DTC = random_search.best_estimator_
accuracy = best_DTC.score(x_test, y_test)
print(f"Accuracy on Test Data: {accuracy:.2f}")
# Out:
# Accuracy on Test Data: 0.88

# %%
max_accuracy = 0
best_random_state = 0

# Iterate through random states from 0 to 500
for random_state in range(501):
    # Create a Random Forest Classifier with the current random state
    clf1 = DecisionTreeClassifier(criterion='entropy', max_depth=32, max_features=None, random_state=random_state)

    # Train the model
    clf1.fit(x_train, y_train)

    # Make predictions on the test set
    y_pred1 = clf1.predict(x_test)

    # Evaluate the model's performance
    accuracy = accuracy_score(y_test, y_pred1)

    # Update max accuracy and corresponding random state if the current accuracy is higher
    if accuracy > max_accuracy:
        max_accuracy = accuracy
        best_random_state = random_state

# Print the maximum accuracy and corresponding random state
print(f"Best Random State: {best_random_state}, Maximum Accuracy: {max_accuracy}")
# Out:
# Best Random State: 202, Maximum Accuracy: 0.88625

# %%
DTC_pred1 = DTC.predict(x_train)
DTC_acc1= accuracy_score(y_train, DTC_pred1)
DTC_acc1
# Out:
# 0.9996875

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors= 18, weights='uniform', metric='euclidean', p=2)
KNN.fit(x_train, y_train)
KNN_pred = KNN.predict(x_test)
KNN_acc= accuracy_score(y_test, KNN_pred)
KNN_acc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.3075

# %%
print(classification_report(y_test, KNN_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.26      0.21        82
#            1       0.29      0.31      0.30        98
#            2       0.25      0.26      0.25        97
#            3       0.26      0.20      0.23       113
#            4       0.32      0.25      0.28        96
#            5       0.46      0.81      0.59        96
#            6       0.30      0.20      0.24       108
#            7       0.34      0.21      0.26       110
#
#     accuracy                           0.31       800
#    macro avg       0.30      0.31      0.29       800
# weighted avg       0.30      0.31      0.29       800

# %%
param_dist_knc = {
    'n_neighbors': np.arange(1, 21),  # Range of neighbors
    'weights': ['uniform', 'distance'],
    'p': [1, 2]  # 1 for Manhattan distance, 2 for Euclidean distance
}

# %%
random_search = RandomizedSearchCV(estimator=KNN, param_distributions=param_dist_knc, n_iter=10, cv=5, random_state=42)
random_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best hyperparameters:", random_search.best_params_)

# Get the best model
best_knn_model = random_search.best_estimator_

# Evaluate the model on the test set
accuracy = best_knn_model.score(x_test, y_test)
print("Accuracy on the test set:", accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
KNN_pred1 = KNN.predict(x_train)
KNN_acc1 = accuracy_score(y_train, KNN_pred1)
KNN_acc1
# Out:
# 0.376875

# %% [markdown]
# # **LR**

# %%
from sklearn.linear_model import LogisticRegression
LC = LogisticRegression( penalty= 'none', solver= 'newton-cg', max_iter= 200, C=30)
LC.fit(x_train, y_train)
LC_pred = LC.predict(x_test)
LC_acc = accuracy_score(y_test, LC_pred)
LC_acc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# ...

# %%
print(classification_report(y_test, LC_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        82
#            1       1.00      0.93      0.96        98
#            2       1.00      0.95      0.97        97
#            3       1.00      0.96      0.98       113
#            4       1.00      0.94      0.97        96
#            5       1.00      0.97      0.98        96
#            6       0.76      1.00      0.86       108
#            7       1.00      0.95      0.98       110
#
#     accuracy                           0.96       800
#    macro avg       0.97      0.96      0.96       800
# weighted avg       0.97      0.96      0.96       800

# %%
LC_pred1 = LC.predict(x_train)
LC_acc1 = accuracy_score(y_train, LC_pred1)
LC_acc1
# Out:
# 0.960625

# %%
param_dist_LR = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': np.logspace(-4, 4, 20),  # Regularization parameter
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'max_iter': [50, 100, 200, 300]
}

# %%
random_search = RandomizedSearchCV(estimator=LC, param_distributions=param_dist_LR, n_iter=10, cv=5, random_state=42)
random_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best hyperparameters:", random_search.best_params_)

# Get the best model
best_LR_model = random_search.best_estimator_

# Evaluate the model on the test set
accuracy = best_LR_model.score(x_test, y_test)
print("Accuracy on the test set:", accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# # **SVC**

# %%
from sklearn.svm import SVC
svc = SVC(C=1000, cache_size=200, decision_function_shape='ovr', degree=5, gamma='scale', kernel='poly', max_iter=-1, shrinking=True, tol=0.001)

# Train the model on the training set
svc.fit(x_train, y_train)

# Predict the labels on the test set
y_pred = svc.predict(x_test)

# Evaluate the model on the test set
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy on Test Set:", accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy on Test Set: 0.2575

# %%
svc_pred1 = svc.predict(x_train)
svc_acc1 = accuracy_score(y_train, svc_pred1)
svc_acc1
# Out:
# 0.281875

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.43      0.24        82
#            1       0.23      0.33      0.27        98
#            2       0.14      0.11      0.13        97
#            3       0.83      0.09      0.16       113
#            4       0.17      0.07      0.10        96
#            5       0.34      0.98      0.50        96
#            6       0.44      0.16      0.23       108
#            7       0.00      0.00      0.00       110
#
#     accuracy                           0.26       800
#    macro avg       0.29      0.27      0.20       800
# weighted avg       0.30      0.26      0.20       800
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # **XGBOOST**

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from xgboost import XGBClassifier
xgb_classifier = XGBClassifier()
param_dist_xgbc = {
    'learning_rate': [0.01, 0.1, 0.2, 0.3],
    'n_estimators': [50, 100, 200, 300],
    'max_depth': [3, 4, 5, 6, 8, 10],
    'min_child_weight': [1, 3, 5, 7],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'gamma': [0, 0.1, 0.2, 0.3, 0.4],
    'objective': ['multi:softmax'],
    'num_class': [3],  # Number of classes in the target variable
}

# Perform randomized search with cross-validation
random_search = RandomizedSearchCV(estimator=xgb_classifier, param_distributions=param_dist_xgbc, n_iter=10, cv=5, random_state=42)
random_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best hyperparameters:", random_search.best_params_)

# Get the best model
best_xgb_model = random_search.best_estimator_

# Evaluate the model on the test set
accuracy = best_xgb_model.score(x_test, y_test)
print("Accuracy on the test set:", accuracy)
# Out:
# Best hyperparameters: {'subsample': 0.8, 'objective': 'multi:softmax', 'num_class': 3, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.3, 'colsample_bytree': 1.0}
# Accuracy on the test set: 0.8825

# %%
XGBC = XGBClassifier(subsample= 1, objective= 'multi:softmax', num_class= 8, n_estimators= 1000, min_child_weight= 1, max_depth= 4, learning_rate= 0.3, gamma= 0.0001, colsample_bytree= 1.0)
XGBC.fit(x_train, y_train)
XGBC_pred = XGBC.predict(x_test)
XGBC_acc = accuracy_score(y_test, XGBC_pred)
XGBC_acc
# Out:
# 0.905

# %%
print(classification_report(y_test, XGBC_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        82
#            1       0.86      0.89      0.87        98
#            2       0.94      0.91      0.92        97
#            3       0.92      0.87      0.89       113
#            4       0.90      0.91      0.90        96
#            5       0.90      0.98      0.94        96
#            6       0.92      0.93      0.92       108
#            7       0.86      0.86      0.86       110
#
#     accuracy                           0.91       800
#    macro avg       0.91      0.91      0.91       800
# weighted avg       0.91      0.91      0.90       800

# %%
from sklearn.model_selection import cross_validate
x= np.concatenate((x_train, x_test), axis=0)
y= np.concatenate((y_train, y_test), axis=0)

# %%
CV_XGBC= cross_validate(estimator=XGBC, X=x, y=y, cv=10, scoring='accuracy', return_train_score=True)
CV_XGBC
train_accuracies1 = CV_XGBC['train_score']
test_accuracies1 = CV_XGBC['test_score']
mean_train_accuracy1 = np.mean(train_accuracies1)
mean_test_accuracy1 = np.mean(test_accuracies1)
print("Train Accuracy Scores:", train_accuracies1)
print("Test Accuracy Scores:", test_accuracies1)
print("\nMean Train Accuracy:", mean_train_accuracy1)
print("Mean Test Accuracy:", mean_test_accuracy1)
# Out:
# Train Accuracy Scores: [0.9575     0.95805556 0.95888889 0.95888889 0.95805556 0.96055556
#  0.95972222 0.95916667 0.95888889 0.95638889]
# Test Accuracy Scores: [0.91   0.8575 0.9075 0.905  0.92   0.9    0.915  0.8775 0.9275 0.9125]
#
# Mean Train Accuracy: 0.9586111111111112
# Mean Test Accuracy: 0.9032499999999999

# %%
XGBC_pred1 = XGBC.predict(x_train)
XGBC_acc1 = accuracy_score(y_train, XGBC_pred1)
XGBC_acc1
# Out:
# 0.9578125

# %% [markdown]
# # **Naive Bayes**

# %% [markdown]
# # New Section

# %%
from sklearn.naive_bayes import GaussianNB
naive_bayes_classifier = GaussianNB(var_smoothing=1.52e-09)

# Train the classifier on the training set
naive_bayes_classifier.fit(x_train, y_train)

# Make predictions on the test set
naive_bayes_classifier_pred = naive_bayes_classifier.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, naive_bayes_classifier_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.21625
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(classification_report(y_test, naive_bayes_classifier_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.13      0.34      0.19        82
#            1       0.16      0.49      0.24        98
#            2       0.03      0.01      0.02        97
#            3       0.00      0.00      0.00       113
#            4       0.00      0.00      0.00        96
#            5       0.38      0.92      0.54        96
#            6       0.50      0.07      0.13       108
#            7       0.00      0.00      0.00       110
#
#     accuracy                           0.22       800
#    macro avg       0.15      0.23      0.14       800
# weighted avg       0.15      0.22      0.13       800
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
CV_naive_bayes_classifier= cross_validate(estimator=naive_bayes_classifier, X=x, y=y, cv=10, scoring='accuracy', return_train_score=True)
CV_naive_bayes_classifier
train_accuracies1 = CV_naive_bayes_classifier['train_score']
test_accuracies1 = CV_naive_bayes_classifier['test_score']
mean_train_accuracy1 = np.mean(train_accuracies1)
mean_test_accuracy1 = np.mean(test_accuracies1)
print("Train Accuracy Scores:", train_accuracies1)
print("Test Accuracy Scores:", test_accuracies1)
print("\nMean Train Accuracy:", mean_train_accuracy1)
print("Mean Test Accuracy:", mean_test_accuracy1)
# Out:
# Train Accuracy Scores: [0.21277778 0.23638889 0.22861111 0.21722222 0.24361111 0.22916667
#  0.23305556 0.22777778 0.235      0.23777778]
# Test Accuracy Scores: [0.26   0.215  0.25   0.23   0.2125 0.215  0.2175 0.2225 0.2225 0.24  ]
#
# Mean Train Accuracy: 0.23013888888888884
# Mean Test Accuracy: 0.2285
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

# Create a Gaussian Naive Bayes classifier
naive_bayes_classifier = GaussianNB()

# Define hyperparameter distribution
param_dist = {
    'var_smoothing': np.logspace(-9, 0, 1000)
}

# Perform randomized search with cross-validation
random_search = RandomizedSearchCV(estimator=naive_bayes_classifier, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
random_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best hyperparameters:", random_search.best_params_)

# Get the best model
best_naive_bayes_model = random_search.best_estimator_

# Make predictions on the test set
y_pred = best_naive_bayes_model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Display classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# # **Ada Boost**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

# Create a base Decision Tree classifier (you can replace it with another classifier if needed)
base_classifier = DecisionTreeClassifier()

# Create an AdaBoost classifier
adaboost_classifier = AdaBoostClassifier(base_classifier)

# Define hyperparameter distribution
param_dist_ada = {
    'n_estimators': [50, 100, 200, 300],
    'learning_rate': np.logspace(-3, 0, 100)
}

# Perform randomized search with cross-validation
random_search = RandomizedSearchCV(estimator=adaboost_classifier, param_distributions=param_dist_ada, n_iter=10, cv=5, random_state=42)
random_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best hyperparameters:", random_search.best_params_)

# Get the best model
best_adaboost_model = random_search.best_estimator_

# Make predictions on the test set
y_pred = best_adaboost_model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Display classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
ADBC = AdaBoostClassifier(DecisionTreeClassifier(),n_estimators= 200, learning_rate= 0.008697490026177835)
ADBC.fit(x_train, y_train)
ADBC_pred = ADBC.predict(x_test)
ADBC_acc = accuracy_score(y_test, ADBC_pred)
ADBC_acc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.88875

# %%
print(classification_report(y_test, ADBC_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90        82
#            1       0.91      0.84      0.87        98
#            2       0.85      0.92      0.88        97
#            3       0.88      0.80      0.84       113
#            4       0.88      0.92      0.90        96
#            5       0.99      0.95      0.97        96
#            6       0.90      0.92      0.91       108
#            7       0.83      0.88      0.85       110
#
#     accuracy                           0.89       800
#    macro avg       0.89      0.89      0.89       800
# weighted avg       0.89      0.89      0.89       800

# %%
ADBC_pred1 = ADBC.predict(x_train)
ADBC_acc1 = accuracy_score(y_train, ADBC_pred1)
ADBC_acc1
# Out:
# 0.9996875

# %%
CV_ADBC= cross_validate(estimator=ADBC, X=x, y=y, cv=10, scoring='accuracy', return_train_score=True)
CV_ADBC
train_accuracies1 = CV_ADBC['train_score']
test_accuracies1 = CV_ADBC['test_score']
mean_train_accuracy1 = np.mean(train_accuracies1)
mean_test_accuracy1 = np.mean(test_accuracies1)
print("Train Accuracy Scores:", train_accuracies1)
print("Test Accuracy Scores:", test_accuracies1)
print("\nMean Train Accuracy:", mean_train_accuracy1)
print("Mean Test Accuracy:", mean_test_accuracy1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
